# %%
# !pip install pytube --user
# Out:
# Requirement already satisfied: pytube in c:\python311\lib\site-packages (15.0.0)

# %%
import os
import json
from pytube import YouTube

def download_video_info(video_url, output_directory='downloads'):
    try:
        # Create a YouTube object
        yt = YouTube(video_url)

        # Create a directory for downloads if it doesn't exist
        if not os.path.exists(output_directory):
            os.makedirs(output_directory)

        # Get the highest resolution audio stream
        audio_stream = yt.streams.filter(only_audio=True).first()

        # Download the audio stream
        audio_path = os.path.join(output_directory)
        print(f"Downloading audio to {audio_path}...")
        audio_stream.download(output_directory,filename=f'{yt.title}.mp3')

        # Collect video information
        video_info = {
            'title': yt.title,
            'duration': yt.length,
            'author': yt.author,
            'views': yt.views,
            'description': yt.description,
            'audio_path': audio_path
        }

        return video_info

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

def process_video_links(file_path):
    with open(file_path, 'r') as file:
        video_links = file.readlines()

    video_data_list = []

    for video_link in video_links:
        video_link = video_link.strip()
        video_info = download_video_info(video_link)
        
        if video_info:
            video_data_list.append(video_info)

    # Save video data to a JSON file
    output_json_path = 'video_data.json'
    with open(output_json_path, 'w') as json_file:
        json.dump(video_data_list, json_file, indent=2)

    print(f'Video data saved to {output_json_path}')

# Replace 'YOUR_TEXT_FILE_PATH' with the path to your text file containing video links
text_file_path = './YT_Clones/Fireship_clone/@Fireship-shorts.txt'

# Process video links and save data to JSON
process_video_links(text_file_path)
# Out:
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\how big is a yottabyte?.mp3'
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\my code works… why?.mp3'
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\r u even turing complete?.mp3'
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\WTF is a Bézier Curve?.mp3'
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\WTF is an Abstract Syntax Tree?.mp3'
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\Why do computers use RGB for colors, and not RBY?.mp3'
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\Is your memory leaking?.mp3'
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 22] Invalid argument: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\Why do computers suck at math?.mp3'
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# Downloading audio to downloads...
# An error occurred: [Errno 2] No such file or directory: 'c:\\Projects\\LLM-Cookbook\\Projects\\downloads\\VS Code Path Trick w/ JavaScript #Shorts.mp3'
# Downloading audio to downloads...
# Video data saved to video_data.json

# %%
import pafy 
  
# url of video 
url = "https://youtu.be/Ns4LCeeOFS4?si=L-6CXV8MScb3m4TV"
  
# instant created 
video = pafy.new(url) 
  
# print title 
print(video.title) 
  
# print rating 
print(video.rating) 
  
# print viewcount 
print(video.viewcount) 
  
# print author & video length 
print(video.author, video.length) 
  
# print duration, likes, dislikes & description 
print(video.duration, video.likes, video.dislikes, video.description)
